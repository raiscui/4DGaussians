# %%
# %cd /content
# !git clone https://github.com/hustvl/4DGaussians
# %cd 4DGaussians

# (可选) 如果你需要代理,取消注释并按需修改.
# import os
# os.environ["https_proxy"] = "http://127.0.0.1:7897"
# os.environ["http_proxy"] = "http://127.0.0.1:7897"
# os.environ["all_proxy"] = "socks5://127.0.0.1:7897"

# 确保在仓库根目录执行 submodule 更新.
import os
from pathlib import Path
repo_dir = Path("/content/4DGaussians")
if repo_dir.exists():
    os.chdir(repo_dir)

# !git submodule update --init --recursive

# 安装 pixi(如果还没有). pixi 默认安装到 ~/.pixi/bin
# !command -v pixi >/dev/null 2>&1 || (curl -fsSL https://pixi.sh/install.sh | sh)

# 让后续的 `!pixi ...` 都能找到 pixi
pixi_bin = str(Path.home() / ".pixi" / "bin")
os.environ["PATH"] = f"{pixi_bin}:{os.environ.get('PATH','')}"

# !pixi --version

# %%
# !sudo apt-get update
# !sudo apt-get install build-essential -y

# %%
# !sudo apt-get install libglm-dev

# %%
# !export https_proxy=http://127.0.0.1:7897 http_proxy=http://127.0.0.1:7897 all_proxy=socks5://127.0.0.1:7897
# 安装项目依赖(会创建 .pixi 环境,并安装 PyTorch CUDA wheel)
# !pixi install || (mkdir -p .pixi && cp -f pixi.mirrors.toml .pixi/config.toml && pixi install)

# 编译并安装本项目的 CUDA 扩展(在 pixi 环境内执行)

# !pixi run install-ext

# %%
import os

# Add #include <cfloat> to simple_knn.cu
with open('submodules/simple-knn/simple_knn.cu', 'r+') as f:
    content = f.read()
    if '#include <cfloat>' not in content:
        f.seek(0) # Rewind to the beginning
        f.write('#include <cfloat>\n' + content)
        print("Added #include <cfloat> to simple_knn.cu")
    else:
        print("#include <cfloat> already present in simple_knn.cu")



# Reinstall both submodules
# !pixi run python -m pip install -e submodules/depth-diff-gaussian-rasterization
# !pixi run python -m pip install -e submodules/simple-knn

# %%
# 简单自检: 打印 torch 与 CUDA 版本
# !pixi run python -c "import torch; print('torch:', torch.__version__); print('cuda:', torch.version.cuda); print('cuda available:', torch.cuda.is_available())"

# %%
# !wget https://huggingface.co/camenduru/4DGaussians/resolve/main/data/data.zip
# !unzip data.zip

# %%
# !pixi run pip install imageio[ffmpeg]

# %% [markdown]
# # **Bouncing Balls**

# %%
# %cd /content/4DGaussians
# !pixi run python train.py -s /content/test/data/bouncingballs --port 6017 --expname "dnerf/bouncingballs" --configs arguments/dnerf/bouncingballs.py

# %%
# %cd /content/4DGaussians
# !pixi run python render.py --model_path "output/dnerf/bouncingballs/"  --skip_train --configs arguments/dnerf/bouncingballs.py

# %%
from IPython.display import HTML
from base64 import b64encode
def display_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=1000 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
save_dir = '/content/4DGaussians/output/dnerf/bouncingballs/video/ours_20000/video_rgb.mp4'

import os
import glob
# video_path = glob.glob(os.path.join(save_dir, "*-test.mp4"))[0]
display_video(save_dir)

# %%
# %cd /content/4DGaussians
# !pixi run python render.py --model_path "output/dnerf/bouncingballs/"  --skip_train --configs arguments/dnerf/bouncingballs.py

# %%
from IPython.display import HTML
from base64 import b64encode
def display_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=1000 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
save_dir = '/content/4DGaussians/output/dnerf/bouncingballs/video/ours_20000/video_rgb.mp4'

import os
import glob
# video_path = glob.glob(os.path.join(save_dir, "*-test.mp4"))[0]
display_video(save_dir)

# %% [markdown]
# # **Hell warrior**

# %%
# %cd /content/4DGaussians
# !pixi run python train.py -s /content/test/data/hellwarrior/ --port 6017 --expname "dnerf/hellwarrior" --configs arguments/dnerf/hellwarrior.py

# %%
# %cd /content/4DGaussians
# !pixi run python render.py --model_path "output/dnerf/hellwarrior/"  --skip_train --configs arguments/dnerf/hellwarrior.py

# %%
from IPython.display import HTML
from base64 import b64encode
def display_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=1000 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
save_dir = '/content/4DGaussians/output/dnerf/hellwarrior/video/ours_20000/video_rgb.mp4'

import os
import glob
# video_path = glob.glob(os.path.join(save_dir, "*-test.mp4"))[0]
display_video(save_dir)

# %% [markdown]
# # **Hook**

# %%
# %cd /content/4DGaussians
# !pixi run python train.py -s /content/test/data/hook --port 6017 --expname "dnerf/hook" --configs arguments/dnerf/hook.py

# %%
# %cd /content/4DGaussians
# !pixi run python render.py --model_path "output/dnerf/hook/"  --skip_train --configs arguments/dnerf/hook.py

# %%
from IPython.display import HTML
from base64 import b64encode
def display_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=1000 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
save_dir = '/content/4DGaussians/output/dnerf/hook/video/ours_20000/video_rgb.mp4'

import os
import glob
# video_path = glob.glob(os.path.join(save_dir, "*-test.mp4"))[0]
display_video(save_dir)

# %% [markdown]
# # **Jumping Jacks**

# %%
# %cd /content/4DGaussians
# !pixi run python train.py -s /content/test/data/jumpingjacks --port 6017 --expname "dnerf/jumpingjacks" --configs arguments/dnerf/jumpingjacks.py

# %%
# %cd /content/4DGaussians
# !pixi run python render.py --model_path "output/dnerf/jumpingjacks/"  --skip_train --configs arguments/dnerf/jumpingjacks.py

# %%
from IPython.display import HTML
from base64 import b64encode
def display_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=1000 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
save_dir = '/content/4DGaussians/output/dnerf/jumpingjacks/video/ours_20000/video_rgb.mp4'

import os
import glob
# video_path = glob.glob(os.path.join(save_dir, "*-test.mp4"))[0]
display_video(save_dir)

# %% [markdown]
# # **Lego**

# %%
# %cd /content/4DGaussians
# !pixi run python train.py -s /content/test/data/lego --port 6017 --expname "dnerf/lego" --configs arguments/dnerf/lego.py

# %%
# %cd /content/4DGaussians
# !pixi run python render.py --model_path "output/dnerf/lego/"  --skip_train --configs arguments/dnerf/lego.py

# %%
from IPython.display import HTML
from base64 import b64encode
def display_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=1000 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
save_dir = '/content/4DGaussians/output/dnerf/lego/video/ours_20000/video_rgb.mp4'

import os
import glob
# video_path = glob.glob(os.path.join(save_dir, "*-test.mp4"))[0]
display_video(save_dir)

# %% [markdown]
# # **Mutant**

# %%
# %cd /content/4DGaussians
# !pixi run python train.py -s /content/test/data/mutant --port 6017 --expname "dnerf/mutant" --configs arguments/dnerf/mutant.py

# %%
# %cd /content/4DGaussians
# !pixi run python render.py --model_path "output/dnerf/mutant/"  --skip_train --configs arguments/dnerf/mutant.py

# %%
from IPython.display import HTML
from base64 import b64encode
def display_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=1000 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
save_dir = '/content/4DGaussians/output/dnerf/mutant/video/ours_20000/video_rgb.mp4'

import os
import glob
# video_path = glob.glob(os.path.join(save_dir, "*-test.mp4"))[0]
display_video(save_dir)

# %% [markdown]
# # **Standup**

# %%
# %cd /content/4DGaussians
# !pixi run python train.py -s /content/test/data/standup --port 6017 --expname "dnerf/standup" --configs arguments/dnerf/standup.py

# %%
# %cd /content/4DGaussians
# !pixi run python render.py --model_path "output/dnerf/standup/"  --skip_train --configs arguments/dnerf/standup.py

# %%
from IPython.display import HTML
from base64 import b64encode
def display_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=1000 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
save_dir = '/content/4DGaussians/output/dnerf/standup/video/ours_20000/video_rgb.mp4'

import os
import glob
# video_path = glob.glob(os.path.join(save_dir, "*-test.mp4"))[0]
display_video(save_dir)

# %% [markdown]
# # **Trex**

# %%
# %cd /content/4DGaussians
# !pixi run python train.py -s /content/test/data/trex --port 6017 --expname "dnerf/trex" --configs arguments/dnerf/trex.py

# %%
# %cd /content/4DGaussians
# !pixi run python render.py --model_path "output/dnerf/trex/"  --skip_train --configs arguments/dnerf/trex.py

# %%
from IPython.display import HTML
from base64 import b64encode
def display_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=1000 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
save_dir = '/content/4DGaussians/output/dnerf/trex/video/ours_20000/video_rgb.mp4'

import os
import glob
# video_path = glob.glob(os.path.join(save_dir, "*-test.mp4"))[0]
display_video(save_dir)

# %% [markdown]
# ---

# %%
pixi run train   -s data/multipleview/bar-release_fullres_0_61  --expname "multipleview/latiqin" --configs arguments/multipleview/default.py   --resolution 4

# %%
pixi run python render.py --model_path "output"  --skip_train --configs arguments/multipleview/default.py
